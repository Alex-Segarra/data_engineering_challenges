# %% [markdown]
# # Data Mart Reports Test

# %% [markdown]
# ### This demonstrates that the data model is indeed working properly and that the appropriate queries are possible.

# %% [markdown]
# ##### Imports

# %%
import pandas as pd
import psycopg2
import json
import subprocess

# %% [markdown]
# ##### DB Connection

# %%
file=json.load(open('creds.json'))

conn = psycopg2.connect(database='data_mart',\
                        user=file['username'],\
                        password=file['password'],\
                        host='127.0.0.1',\
                        port= '5432')

cursor = conn.cursor()

# %% [markdown]
# ##### Schema Test and Reference

# %%
#Select all table names in data_mart
sql = """
SELECT table_schema
        , table_name 
FROM 
    information_schema.tables
WHERE 
    table_schema NOT IN ('pg_catalog', 'information_schema')"""
cursor.execute(sql)
cursor.fetchall()
#{t[0]:t[1] for t in cursor.fetchall()}
# Out:
# [('loads', 'tmp_import'),
#  ('customer_data', 'customers'),
#  ('customer_data', 'address_history'),
#  ('order_data', 'order_details'),
#  ('order_data', 'orders')]

# %% [markdown]
# ##### Requirement: The ability to look at the total number of orders shipped to a specific state in a given year

# %%
sql ="""
WITH base AS (
    
SELECT
order_id
, state
, CAST(EXTRACT(YEAR FROM order_date) as int) AS year
FROM
customer_data.address_history
INNER JOIN 
order_data.orders
USING (customer_id)

)

SELECT
year
, state
, COUNT(order_id) AS orders
FROM
base
GROUP BY
year
, state
ORDER BY
state
, year
"""

pd.read_sql(sql, conn)
# Out:
# /var/tmp/ipykernel_45513/384042218.py:31: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql(sql, conn)
#     year state  orders
# 0   2014    AK       1
# 1   2015    AK       2
# 2   2016    AK       1
# 3   2016    AZ       1
# 4   2013    CA       2
# 5   2014    CA       3
# 6   2015    CA       3
# 7   2017    CA       1
# 8   2015    CO       1
# 9   2016    CO       1
# 10  2013    FL       3
# 11  2016    FL       2
# 12  2013    HI       2
# 13  2014    HI       1
# 14  2015    HI       1
# 15  2016    HI       1
# 16  2014    ID       1
# 17  2016    ID       1
# 18  2015    IL       1
# 19  2017    IL       1
# 20  2013    IN       1
# 21  2014    IN       1
# 22  2014    KS       2
# 23  2015    KS       1
# 24  2013    MD       1
# 25  2015    MD       1
# 26  2017    MD       1
# 27  2013    NJ       1
# 28  2014    NJ       8
# 29  2015    NJ       5
# 30  2016    NJ       3
# 31  2013    NY       2
# 32  2014    NY       7
# 33  2015    NY       1
# 34  2016    NY       5
# 35  2014    OH       1
# 36  2015    OH       2
# 37  2016    OH       2
# 38  2014    PA       2
# 39  2016    PA       3
# 40  2013    RI       1
# 41  2013    SC       2
# 42  2014    SC       1
# 43  2016    SC       1
# 44  2015    SD       1
# 45  2016    SD       1
# 46  2013    TN       1
# 47  2014    TN       2
# 48  2016    TN       1
# 49  2017    TN       1
# 50  2013    TX       2
# 51  2014    TX       3
# 52  2015    TX       2
# 53  2013    WI       2
# 54  2015    WI       1
# 55  2016    WI       1
# 56  2017    WI       1

# %% [markdown]
# ##### Requirement: The ability to look up all customers current addresses

# %%
sql = """
WITH base AS (
    
SELECT
*
FROM
customer_data.customers
INNER JOIN
customer_data.address_history
USING (customer_id)
)

,agg as (
SELECT DISTINCT
first_name
, last_name
, CASE 
    WHEN end_date = MAX(end_date) OVER (PARTITION BY customer_id) 
    THEN CONCAT(street_number,', ',city,', ',state,' ',postal_code) 
    ELSE null
    END AS address
FROM base
ORDER BY
last_name
, first_name
)

SELECT * FROM agg WHERE address IS NOT NULL
"""
pd.read_sql(sql, conn)
# Out:
# /var/tmp/ipykernel_45513/2960507529.py:32: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql
# 45    Solange     Shinko        84 Bloomfield Ave, Spartanburg, SC 29301
# 46     Mitsue    Tollner                    7 Eads St, Chicago, IL 60632
# 47      Sabra    Uyetake  98839 Hawthorne Blvd #6101, Columbia, SC 29201
# 48      Jamal  Vanausdal              1 N Harlem Ave #9, Orange, NJ 7050
# 49      Carma  Vanheusen              4 Bloomfield Ave, Irving, TX 75061
# 50        Art     Venere       8 W Cerritos Ave #54, Bridgeport, NJ 8014
# 51    Tammara    Wardrip     4800 Black Horse Pike, Burlingame, CA 94010
# 52       Sage     Wieser         5 Boston Ave #88, Sioux Falls, SD 57105
# 53    Maurine   Yglesias            59 Shady Ln #53, Milwaukee, WI 53214

# %% [markdown]
# ##### Summary reports that will show all orders and their order status

# %%
#Summary reports that will show all orders and their order status
print("No status included in sample data provided")
# Out:
# No status included in sample data provided

# %% [markdown]
# ##### Requirement: A way to see what customers did not have order in certain years
# ###### Quote: "Marketing is really interested in evaluating customer order trends"

# %%
#A way to see what customers did not have order in certain years
# ■ Marketing is really interested in evaluating customer order trends

#Strangely worded... I will attempt to find what they did not order by year.

sql = """
WITH base AS (
    
SELECT *, CAST(EXTRACT(year from order_date) as int) as year FROM order_data.orders
INNER JOIN
order_data.order_details
USING (order_id)
)

, products AS (
    
SELECT
DISTINCT
b.product_name
,c.customer_id
,y.year
FROM
base b
CROSS JOIN
(SELECT DISTINCT customer_id FROM base) AS c
CROSS JOIN
(SELECT DISTINCT year FROM base) AS y)

SELECT 
p.product_name, 
customer_id, year, order_date, quantity
FROM products p
LEFT JOIN
base b
USING (product_name,customer_id,year)
WHERE order_date IS NULL
ORDER BY product_name, customer_id, year 
"""

pd.read_sql(sql, con=conn)
# Out:
# /var/tmp/ipykernel_45513/4217004011.py:40: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql(sql, con=conn)
#      product_name                                        customer_id  year  \
# 0        Anzamlax  \x01a68ce3aabaaa3fcc8fa58bfd4f84a044947996fd59...  2013
# 1        Anzamlax  \x01a68ce3aabaaa3fcc8fa58bfd4f84a044947996fd59...  2014
# 2        Anzamlax  \x01a68ce3aabaaa3fcc8fa58bfd4f84a044947996fd59...  2015
# 3        Anzamlax  \x01a68ce3aabaaa3fcc8fa58bfd4f84a044947996fd59...  2016
# 4        Anzamlax  \x01a68ce3aabaaa3fcc8fa58bfd4f84a044947996fd59...  2017
# ...           ...                                                ...   ...
# 6266      Zer Dax  \xf8e87f42ce6114735a829d613995c57b9b5251acdc2f...  2013
# 6267      Zer Dax  \xf8e87f42ce6114735a829d613995c57b9b5251acdc2f...  2014
# 6268      Zer Dax  \xf8e87f42ce6114735a829d613995c57b9b5251acdc2f...  2015
# 6269      Zer Dax  \xf8e87f42ce6114735a829d613995c57b9b5251acdc2f...  2016
# 6270      Zer Dax  \xf8e87f42ce6114735a829d613995c57b9b5251acdc2f...  2017
#
#      order_date quantity
# 0          None     None
# 1          None     None
# 2          None     None
# 3          None     None
# 4          None     None
# ...         ...      ...
# 6266       None     None
# 6267       None     None
# 6268       None     None
# 6269       None     None
# 6270       None     None
#
# [6271 rows x 5 columns]

# %% [markdown]
# ##### Requirement Quarterly Sales reports at the product level as well a quarterly report at the customer level
# ###### Use Case: Product level

# %%
#Quarterly Sales reports at the product level as well a quarterly report at the customer level
# Product level
sql = """
WITH base AS (
SELECT 
product_name
,order_id
,price
,quantity
,customer_id
,order_date
,CAST(EXTRACT(QTR FROM order_date) as int) AS quarter
,CAST(EXTRACT(YEAR FROM order_date) as int) AS year
FROM
order_data.order_details
INNER JOIN
order_data.orders
USING (order_id)
)

SELECT 
year
,quarter
,product_name
,sum(quantity) AS quantity
,sum(price) AS revenue
FROM base
GROUP BY
year
,quarter
,product_name

ORDER BY
product_name
,year
,quarter

"""

pd.read_sql(sql, conn)
# Out:
# /var/tmp/ipykernel_45513/2175147423.py:40: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql(sql, conn)
#      year  quarter product_name  quantity  revenue
# 0    2013        3     Anzamlax       3.0     8.99
# 1    2014        1     Anzamlax      14.0   291.95
# 2    2014        2     Anzamlax       6.0    92.98
# 3    2015        2     Anzamlax       1.0    31.99
# 4    2013        2     Dentodox       1.0     5.99
# ..    ...      ...          ...       ...      ...
# 160  2015        1      Zer Dax       5.0   103.98
# 161  2015        3      Zer Dax       2.0   170.98
# 162  2016        1      Zer Dax       4.0    33.98
# 163  2016        2      Zer Dax       2.0    17.99
# 164  2017        1      Zer Dax       2.0    76.99
#
# [165 rows x 5 columns]

# %% [markdown]
# ##### Requirement Quarterly Sales reports at the product level as well a quarterly report at the customer level
# ###### Use Case: Product level

# %%
#Quarterly Sales reports at the product level as well a quarterly report at the customer level
#Customer level
sql = """
WITH base AS (
SELECT 
product_name
,order_id
,price
,quantity
,customer_id
,order_date
,CAST(EXTRACT(QTR FROM order_date) as int) AS quarter
,CAST(EXTRACT(YEAR FROM order_date) as int) AS year
FROM
order_data.order_details
INNER JOIN
order_data.orders
USING (order_id)
)

SELECT 
year
,quarter
,first_name
,last_name
,customer_id
,sum(quantity) AS quantity
,sum(price) AS revenue
FROM base
INNER JOIN
customer_data.customers
USING (customer_id)
GROUP BY
year
,quarter
,first_name
,last_name
,customer_id
ORDER BY
last_name
,first_name
,year
,quarter
"""

pd.read_sql(sql, conn)
# Out:
# /var/tmp/ipykernel_45513/1125860472.py:46: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql(sql, conn)
#     year  quarter first_name  last_name  \
# 0   2015        2      Cammy    Albares
# 1   2014        1      Minna     Amigon
# 2   2016        2      Minna     Amigon
# 3   2015        3  Stephaine   Barfield
# 4   2013        4     Kallie  Blackwood
# ..   ...      ...        ...        ...
# 82  2015        1    Tammara    Wardrip
# 83  2015        3    Tammara    Wardrip
# 84  2015        3       Sage     Wieser
# 85  2016        4       Sage     Wieser
# 86  2013        2    Maurine   Yglesias
#
#                                           customer_id  quantity  revenue
# 0   \x7ba38823694b2ad8022642df27d970f814e575365a38...      11.0   128.96
# 1   \x04e39f45829b3256718e228e2c69e2ff10cc4102a6b8...       6.0    95.98
# 2   \x04e39f45829b3256718e228e2c69e2ff10cc4102a6b8...       2.0    45.99
# 3   \x7ad02460a8f832e6972a6baee7239524a14a6b97d923...      10.0   156.97
# 4   \x9da682d8f85d2aa70b915d8941eef3c32854839a2d4b...       5.0    54.98
# ..                                                ...       ...      ...
# 82  \x607e1d0536b2377fb3675a38c9441a3626328556e28f...       5.0    92.98
# 83  \x607e1d0536b2377fb3675a38c9441a3626328556e28f...       1.0     7.99
# 84  \x828533f54460fca012eea44a8724e51c1c5487b05f8d...       5.0    67.98
# 85  \x828533f54460fca012eea44a8724e51c1c5487b05f8d...       4.0    18.99
# 86  \xcc769c0fe18084f00c3c0ddd5c223d6261e846b29fba...      12.0   193.95
#
# [87 rows x 7 columns]
